# %%
import ipywidgets as widgets
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp

# %%
df = pd.read_csv("data/xaa.csv")

# %%
df2 = pd.read_csv("data/xab.csv")

# %%
df3 = pd.read_csv("data/xac.csv")

# %%
df4 = pd.read_csv("data/xad.csv")

# %%
df5 = pd.read_csv("data/xae.csv")

# %%
df6 = pd.read_csv("data/xaf.csv")

# %%
df7 = pd.read_csv("data/xag.csv")

# %%
print(df)
# Out:
#                             prov_insc      cant_insc  \
# 0                        Santa Elena     Santa Elena
# 1                        Santa Elena     Santa Elena
# 2                        Santa Elena     Santa Elena
# 3                        Santa Elena     Santa Elena
# 4                        Santa Elena     Santa Elena
# 5                        Santa Elena     Santa Elena
# 6                        Santa Elena     Santa Elena
# 7                        Santa Elena     Santa Elena
# 8                        Santa Elena     Santa Elena
# 9                        Santa Elena     Santa Elena
# 10                       Santa Elena     Santa Elena
# 11                       Santa Elena     Santa Elena
# 12                       Santa Elena     Santa Elena
# 13                       Santa Elena     Santa Elena
# 14                       Santa Elena     Santa Elena
# 15                       Santa Elena     Santa Elena
# 16                       Santa Elena         Salinas
# ...

# %%
print(df2)
# Out:
#        prov_insc cant_insc  parr_insc  anio_insc    mes_insc dia_insc  \
# 0      Pichincha     Quito  Itchimbia       2017       Julio       20
# 1      Pichincha     Quito  Itchimbia       2017       Julio        4
# 2      Pichincha     Quito  Itchimbia       2017       Julio        7
# 3      Pichincha     Quito  Itchimbia       2017       Junio       26
# 4      Pichincha     Quito  Itchimbia       2017       Junio       28
# 5      Pichincha     Quito  Itchimbia       2017       Junio       27
# 6      Pichincha     Quito  Itchimbia       2017       Julio        7
# 7      Pichincha     Quito  Itchimbia       2017      Agosto        9
# 8      Pichincha     Quito  Itchimbia       2017       Junio       20
# 9      Pichincha     Quito  Itchimbia       2017       Junio       22
# 10     Pichincha     Quito  Itchimbia       2017       Junio       23
# 11     Pichincha     Quito  Itchimbia       2017       Junio       14
# ...

# %%
frames = [df, df2, df3, df4, df5, df6, df7]

# %%
result = pd.concat(frames)

# %%
print result
# Out:
#                            prov_insc              cant_insc  \
# 0                       Santa Elena             Santa Elena
# 1                       Santa Elena             Santa Elena
# 2                       Santa Elena             Santa Elena
# 3                       Santa Elena             Santa Elena
# 4                       Santa Elena             Santa Elena
# 5                       Santa Elena             Santa Elena
# 6                       Santa Elena             Santa Elena
# 7                       Santa Elena             Santa Elena
# 8                       Santa Elena             Santa Elena
# 9                       Santa Elena             Santa Elena
# 10                      Santa Elena             Santa Elena
# 11                      Santa Elena             Santa Elena
# 12                      Santa Elena             Santa Elena
# 13                      Santa Elena             Santa Elena
# 14                      Santa Elena             Santa Elena
# ...

# %%
result.head()
# Out:
#       prov_insc    cant_insc    parr_insc anio_insc         mes_insc  \
# 0  Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 1  Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 2  Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 3  Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 4  Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
#
#           dia_insc  fecha_insc    sexo  anio_nac     mes_nac      ...       \
# 0  Sin informaci�n  2017-99-99   Mujer      2017       Abril      ...
# 1  Sin informaci�n  2017-99-99  Hombre      2017       Marzo      ...
# 2  Sin informaci�n  2017-99-99  Hombre      2017       Junio      ...
# 3  Sin informaci�n  2017-99-99  Hombre      2017  Septiembre      ...
# 4  Sin informaci�n  2017-99-99  Hombre      2017       Julio      ...
#
#           hij_nacm            etnia        est_civil         niv_inst  \
# ...

# %%
result['peso'] = result['peso'].replace(u'Sin Información', 0)

# %%
from IPython.display import display

w = widgets.Dropdown(
    options=[u'Salinas', u'Santa Elena', u'Guayaquil', u'La Libertad',u'Mejia', u'Pangua', u'Sigchos'],
    value=u'Santa Elena',
    description='Cantones:',
    disabled=False,
)
display(w)
# Out:
# RHJvcGRvd24oZGVzY3JpcHRpb249dSdDYW50b25lczonLCBpbmRleD0xLCBvcHRpb25zPSh1J1NhbGluYXMnLCB1J1NhbnRhIEVsZW5hJywgdSdHdWF5YXF1aWwnLCB1J0xhIExpYmVydGFkJyzigKY=

# %%
result[result['cant_insc']==w.value]
# Out:
#          prov_insc    cant_insc    parr_insc anio_insc         mes_insc  \
# 0     Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 1     Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 2     Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 3     Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 4     Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 5     Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 6     Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 7     Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 8     Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 9     Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 10    Santa Elena   Santa Elena  Santa Elena      2017  Sin informaci�n
# 11    Santa Elena   Santa Elena     Colonche      2017  Sin informaci�n
# ...

# %%
from IPython.display import display

w = widgets.Dropdown(
    options=[u'Santa Elena', u'Guayas', u'Esmeraldas', u'El Oro',u'Manabí', u'Los Ríos'],
    value=u'Esmeraldas',
    description='Costa:',
    disabled=False,
)
display(w)
# Out:
# RHJvcGRvd24oZGVzY3JpcHRpb249dSdDb3N0YTonLCBpbmRleD0yLCBvcHRpb25zPSh1J1NhbnRhIEVsZW5hJywgdSdHdWF5YXMnLCB1J0VzbWVyYWxkYXMnLCB1J0VsIE9ybycsIHUnTWFuYWLigKY=

# %%
result[result['cant_insc']==w.value]
# Out:
#         prov_insc   cant_insc   parr_insc anio_insc         mes_insc  \
# 1050   Esmeraldas  Esmeraldas  Esmeraldas      2017  Sin informaci�n
# 1051   Esmeraldas  Esmeraldas  Esmeraldas      2017  Sin informaci�n
# 1052   Esmeraldas  Esmeraldas  Esmeraldas      2017  Sin informaci�n
# 1053   Esmeraldas  Esmeraldas  Esmeraldas      2017  Sin informaci�n
# 1054   Esmeraldas  Esmeraldas  Esmeraldas      2017  Sin informaci�n
# 1055   Esmeraldas  Esmeraldas  Esmeraldas      2017  Sin informaci�n
# 1056   Esmeraldas  Esmeraldas  Esmeraldas      2017  Sin informaci�n
# 1057   Esmeraldas  Esmeraldas  Esmeraldas      2017  Sin informaci�n
# 1058   Esmeraldas  Esmeraldas  Esmeraldas      2017  Sin informaci�n
# 1059   Esmeraldas  Esmeraldas  Esmeraldas      2017  Sin informaci�n
# 1060   Esmeraldas  Esmeraldas  Esmeraldas      2018  Sin informaci�n
# 1061   Esmeraldas  Esmeraldas  Esmeraldas      2018  Sin informaci�n
# 1062   Esmeraldas  Esmeraldas  Esmeraldas      2018  Sin informaci�n
# ...

# %%
from IPython.display import display

w = widgets.Dropdown(
    options=[u'Loja', u'Imbabura', u'Pichincha',u'Tungurahua', u'Azuay', u'Chimborazo', u'Cotopaxi', u'Carchi', u'Bolívar', u' Cañar'],
    value=u'Azuay',
    description='Sierra:',
    disabled=False,
)
display(w)

w1 = widgets.Dropdown(
    options=[u'Cesárea', u'Normal'],
    value=u'Cesárea',
    description='Tipo_Parto:',
    disabled=False,
)
display(w1)
# Out:
# RHJvcGRvd24oZGVzY3JpcHRpb249dSdTaWVycmE6JywgaW5kZXg9NCwgb3B0aW9ucz0odSdMb2phJywgdSdJbWJhYnVyYScsIHUnUGljaGluY2hhJywgdSdUdW5ndXJhaHVhJywgdSdBenVheSfigKY=
# Dropdown(description=u'Tipo_Parto:', options=(u'Ces\xe1rea', u'Normal'), value=u'Ces\xe1rea')

# %%
result[result['prov_insc']==w.value]
result[result['tipo_part']==w1.value]
# Out:
# Empty DataFrame
# Columns: [prov_insc, cant_insc, parr_insc, anio_insc, mes_insc, dia_insc, fecha_insc, sexo, anio_nac, mes_nac, dia_nac, fecha_nac, talla, peso, sem_gest, tipo_part, apgar1, apgar5, p_emb, lugar_ocur, prov_nac, cant_nac, parr_nac, area_nac, asis_por, nac_mad, cod_pais, anio_mad, mes_mad, dia_mad, fecha_mad, edad_mad, con_pren, num_emb, num_par, hij_viv, hij_vivm, hij_nacm, etnia, est_civil, niv_inst, sabe_leer, prov_res, cant_res, parr_res, area_res, residente]
# Index: []
#
# [0 rows x 47 columns]

# %%
plt.figure(figsize=(40,20))
plt.subplot2grid((2,3), (0,1))
result.niv_inst.value_counts(normalize=True).plot(kind='bar')
plt.title(u'Niveles de instrucción%')
# Out:
# Text(0.5,1,u'Niveles de instrucci\xf3n%')

# %%
result.tipo_part.value_counts()[:20].sort_values(inplace=False).plot('barh');
plt.title(u'Tipo de Parto%')
# Out:
# Text(0.5,1,u'Tipo de Parto%')

# %%
plt.figure(figsize=(25,20))
plt.subplot2grid((2,3), (0,1))
result.residente.value_counts(normalize=True).plot(kind='bar')
plt.title(u'Residente%')
# Out:
# Text(0.5,1,u'Residente%')

# %%
result.mes_insc = result.mes_insc.str.replace(u'Sin información','Diciembre')

# %%
print(result)
# Out:
#                            prov_insc              cant_insc  \
# 0                       Santa Elena             Santa Elena
# 1                       Santa Elena             Santa Elena
# 2                       Santa Elena             Santa Elena
# 3                       Santa Elena             Santa Elena
# 4                       Santa Elena             Santa Elena
# 5                       Santa Elena             Santa Elena
# 6                       Santa Elena             Santa Elena
# 7                       Santa Elena             Santa Elena
# 8                       Santa Elena             Santa Elena
# 9                       Santa Elena             Santa Elena
# 10                      Santa Elena             Santa Elena
# 11                      Santa Elena             Santa Elena
# 12                      Santa Elena             Santa Elena
# 13                      Santa Elena             Santa Elena
# 14                      Santa Elena             Santa Elena
# ...

# %%
plt.figure(figsize=(25,20))
plt.subplot2grid((2,3), (0,1))
result.mes_insc.value_counts(normalize=True).plot(kind='bar')
plt.title(u'Mes de Inscripción%')
# Out:
# Text(0.5,1,u'Mes de Inscripci\xf3n%')
